# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
hyperlaplace = [math.exp(- abs(x) ** 0.6) for x in np.linspace(-1, 1, 100)]
plt.plot(np.linspace(-1, 1, 100), hyperlaplace)

# %% [markdown]
# $$p(x) = a * e^{-k * |x|^\alpha}$$
#
#
#
#
# blah
